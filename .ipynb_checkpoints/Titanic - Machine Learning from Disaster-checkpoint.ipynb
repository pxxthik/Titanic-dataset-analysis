# %% [markdown]
# # Titanic EDA:Can money help in death?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ![Alt Text](titanic.jpg)

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Summary of the Data
#
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone on board, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.

# %% [markdown]
# # Column Descriptions
#
# - `survival` - Survival, 0 = No, 1 = Yes
#
# - `pclass` - Ticket class, 1 = 1st, 2 = 2nd, 3 = 3rd
#
# - `sex` - Sex
#
# - `Age` - Age in years
#
# - `sibsp` - No. of siblings/spouse abroad the titanic
#
# - `parch` - No. of parent/children abroad the titanic
#
# - `ticket` - Ticket number
#
# - `fare` - Passesnger fare
#
# - `cabin` - Cabin number
#
# - `embarked` - Port of Embarkation, C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# # Additional Information
#
# The data has been split into two groups:
#
# - training set (train.csv)
# - test set (test.csv)
#
# **The training set** should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each passenger. Your model will be based on “features” like passengers’ gender and class. You can also use feature engineering to create new features.
#
# **The test set** should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth for each passenger. It is your job to predict these outcomes. For each passenger in the test set, use the model you trained to predict whether or not they survived the sinking of the Titanic.

# %%
# export data for manual assessment

df = pd.concat([df, pd.read_csv('test.csv')], ignore_index=True)
df.to_excel('titanic.xlsx')

# %% [markdown]
# ### Issues with the dataset
#
# 1. Dirty Data
#     - **name** - has some passenger name inside brackets row # 1,3,8,9,15,18,...,66 `accuracy`
#     - **name** - has some passenger name in double quotes row # 22, 28,...165, `accuracy`
#     - row # 101,146,148,161,186,...,556 name column contian name in both brackets and quotes `accuracy`
#     - **name** row # 906 starts from small letter `consistency`
#     - **name** row # 910,924,926,943,995,999,1035,... missed the quotes `accuracy`
#     - **Age** has some missing values `completeness`
#     - **Cabin** has some missing values `completeness`
#     - **Embarked** has some missing values `completeness`
#
#
# 2. Messy Data

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 493          494       0.0       1  Artagaveytia, Mr. Ramon  male  71.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 493      0      0  PC 17609  49.5042   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[["Age","Fare"]].describe()
# Out:
#                Age         Fare
# count  1046.000000  1308.000000
# mean     29.881138    33.295479
# std      14.413493    51.758668
# min       0.170000     0.000000
# 25%      21.000000     7.895800
# 50%      28.000000    14.454200
# 75%      39.000000    31.275000
# max      80.000000   512.329200

# %%
df[df['Age'] == 0.420000]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804       1.0       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
df[df['Ticket'] == '2625']
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 803          804       1.0       3            Thomas, Master. Assad Alexander
# 995          996       NaN       3  Thomas, Mrs. Alexander (Thamine Thelma")"
#
#         Sex    Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803    male   0.42      0      1   2625  8.5167   NaN        C
# 995  female  16.00      1      1   2625  8.5167   NaN        C

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# None values on percentage
missing_data = pd.DataFrame({'total_missing':df.isna().sum(),'perc_missing' : df.isna().sum()/df.shape[0]})
missing_data
# Out:
#              total_missing  perc_missing
# PassengerId              0      0.000000
# Survived               418      0.319328
# Pclass                   0      0.000000
# Name                     0      0.000000
# Sex                      0      0.000000
# Age                    263      0.200917
# SibSp                    0      0.000000
# Parch                    0      0.000000
# Ticket                   0      0.000000
# Fare                     1      0.000764
# Cabin                 1014      0.774637
# Embarked                 2      0.001528

# %% [markdown]
# ### Data Cleaning

# %%
df = df.dropna(subset = ['Fare','Embarked']).reset_index(drop=True)

# %% [markdown]
# ### Handling missing values & Feature Engineering

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Age'] = df['Age'].astype('int')

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'C83', 'F33', 'F G73',
#        'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69',
#        'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32',
#        'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87',
#        'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49',
#        'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66',
#        'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128',
#        'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
# ...

# %%
df['deck'] = [None]*df.shape[0]
decks = df[df['Cabin'].notnull()]['Cabin'].str[0]
df.loc.__setitem__((df['Cabin'].notnull().index, ('deck')), decks)

# %%
df.groupby('deck')['Fare'].agg('max').sort_values()
# Out:
# deck
# G     16.7000
# T     35.5000
# F     39.0000
# A     81.8583
# D    113.2750
# E    134.5000
# C    263.0000
# B    512.3292
# Name: Fare, dtype: float64

# %%
deck_categories = ['G', 'T', 'F', 'A', 'D', 'E', 'C', 'B']

conditions = [(df[df['deck'] == 'G']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'G']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'T']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'T']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'F']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'F']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'A']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'A']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'D']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'D']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'E']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'E']['Fare'].max() < df['Fare']) & (df[df['deck'] == 'C']['Fare'].max() >= df['Fare']),
              (df[df['deck'] == 'C']['Fare'].max() < df['Fare'])]

df['deck'] = np.select(conditions, deck_categories)

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        417
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1013
# Embarked          0
# deck              0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
for_vis = df.copy()

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age, Fare, PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch, Embarked
# - **Mixed** - Name, Ticket, Cabin

# %% [markdown]
# ### Univariate Analysis
# <hr/>

# %%
def num_col_analysis(col):
    print(for_vis[col].describe())
    
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))

    sns.histplot(data=for_vis, x=col, ax=axes[0,0])
    axes[0,0].set_title("Histogram of {}".format(col))

    sns.kdeplot(data=for_vis[col], fill=True, ax=axes[0,1])
    axes[0,1].set_title("(KDE) Plot - skew = {}".format(for_vis[col].skew()))

    sns.boxplot(data=for_vis, x=col, ax=axes[1,0])
    axes[1,0].set_title("Box Plot")

    sns.ecdfplot(data=for_vis, x=col, ax=axes[1,1])
    axes[1,1].set_title("ECDF Plot")

    plt.show()

# %% [markdown]
# ### Age
#
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% data is missing
# - There is some outliers

# %%
num_col_analysis('Age')
# Out:
# count    1306.000000
# mean       29.630934
# std        12.854092
# min         0.000000
# 25%        22.000000
# 50%        29.000000
# 75%        35.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Fare
#
# **conclusions**
#
# - Data is heighly(positevly) skewed
# - Fare col actually contains the group fare not the individual fare(this might be an issue)
# - We need to create a new col called individual_fare

# %%
num_col_analysis('Fare')
# Out:
# count    1306.000000
# mean       33.223956
# std        51.765986
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# ### Categorical columns

# %%
def cat_col_analysis(col, explode):
    print(for_vis[col].value_counts())
    
    fig, axes = plt.subplots(ncols=2, figsize=(12, 4))

    sns.countplot(data=for_vis, x=col, ax=axes[0])
    axes[0].set_title("Bar plot of {}".format(col))

    axes[1].pie(for_vis[col].value_counts(),
                  labels=for_vis[col].value_counts().index,
                  explode=explode,
                  autopct='%1.1f%%')
    axes[1].set_title("Pie Chart")

    plt.show()

# %% [markdown]
# ### Survived

# %%
for_vis['Survived'] = for_vis['Survived'].fillna('Unknown')

# %%
cat_col_analysis('Survived', explode=(0,0,0.1))
# Out:
# 0.0        549
# Unknown    417
# 1.0        340
# Name: Survived, dtype: int64

# %% [markdown]
# ### Pclass
#
# **conslusions**
#
# - Surprisingly less peaple travelled in Pclass 2 and more peaple travelled in Pclass 3
# - `Age * Class` - Since age and class are both numbers we can just multiply them.

# %%
cat_col_analysis('Pclass', explode=(0,0.1,0.1))
# Out:
# 3    708
# 1    321
# 2    277
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Sex

# %%
cat_col_analysis('Sex', explode=(0,0))
# Out:
# male      842
# female    464
# Name: Sex, dtype: int64

# %% [markdown]
# ### SibSp

# %%
cat_col_analysis('SibSp', explode=None)
# Out:
# 0    888
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %% [markdown]
# ### Parch
#
# **conclusions**
#
# - Parch and SibSp cols can be merged to form a new col called family_size
# - Create a new col called is_alone

# %%
cat_col_analysis('Parch', explode=None)
# Out:
# 0    999
# 1    170
# 2    113
# 3      8
# 5      6
# 4      6
# 6      2
# 9      2
# Name: Parch, dtype: int64

# %% [markdown]
# ### Embarked
#
# **conclusions**
#
# - Has some missing values

# %%
cat_col_analysis('Embarked', explode=None)
# Out:
# S    913
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
cat_col_analysis('deck', explode=None)
# Out:
# G    731
# T    286
# A    162
# C     56
# D     41
# F     15
# E     11
# B      4
# Name: deck, dtype: int64

# %%
pd.crosstab(df['deck'], df['Survived'], normalize='index').plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='deck'>

# %% [markdown]
# ### Bivariate Analysis
# <hr/>

# %% [markdown]
# ### Survived vs Pclass
#
# **conclusions**
#
# - More peaple died travelling in Pclass 3

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0.0       37.383178  52.717391  75.763747
# 1.0       62.616822  47.282609  24.236253

# %% [markdown]
# ### Survived vs Sex
#
# **conclusion**
#
# - Chance of surviving females are higher than males

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0.0       25.961538  81.109185
# 1.0       74.038462  18.890815

# %% [markdown]
# ### Comparing the number of Survived people by gender to the total number of people

# %%
df_plot = df.groupby(['Sex', 'Survived']).size().reset_index().pivot(columns='Sex', index='Survived', values=0)

df_plot.plot(kind='bar', stacked=True)
plt.title("Sex vs Survived")
plt.show()

# %% [markdown]
# ### Survived vs Embarked
#
# **conclusion**
#
# - More peaple from Cherbourg survived becouse generally they were in 1st class

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0.0       44.642857  61.038961  66.304348
# 1.0       55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Pclass'], df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         52.222222   2.439024  19.386637
# 2         10.370370   5.691057  26.506024
# 3         37.407407  91.869919  54.107338

# %% [markdown]
# ### Survived vs Age

# %%
df[df['Survived'] == 1]['Age'].plot(kind='kde', label='survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='not survived')

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# 37.850467289719624

# %% [markdown]
# ### Does the fare depend on death?

# %%
sns.violinplot(data=df, x="Survived", y="Fare", hue="Sex", split=True, inner="quart")
plt.show()

# %% [markdown]
# ### Pclass vs Age

# %%
sns.boxplot(x="Pclass", y="Age", data=df)
plt.show()

# %% [markdown]
# ### Feature Engineering on Fare col

# %%
df['SibSp'].value_counts()
# Out:
# 0    888
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#       PassengerId  Survived  Pclass                               Name  \
# 158           160       0.0       3         Sage, Master. Thomas Henry
# 179           181       0.0       3       Sage, Miss. Constance Gladys
# 200           202       0.0       3                Sage, Mr. Frederick
# 323           325       0.0       3           Sage, Mr. George John Jr
# 791           793       0.0       3            Sage, Miss. Stella Anna
# 844           847       0.0       3           Sage, Mr. Douglas Bullen
# 861           864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"
# 1076         1080       NaN       3                    Sage, Miss. Ada
# 1230         1234       NaN       3              Sage, Mr. John George
# 1248         1252       NaN       3        Sage, Master. William Henry
# 1253         1257       NaN       3     Sage, Mrs. John (Annie Bullen)
#
#          Sex  Age  SibSp  Parch    Ticket   Fare Cabin Embarked deck
# ...

# %%
df[df['Name'].str.contains('Sage')]
# Out:
#       PassengerId  Survived  Pclass                               Name  \
# 158           160       0.0       3         Sage, Master. Thomas Henry
# 179           181       0.0       3       Sage, Miss. Constance Gladys
# 200           202       0.0       3                Sage, Mr. Frederick
# 323           325       0.0       3           Sage, Mr. George John Jr
# 640           642       1.0       1               Sagesser, Mlle. Emma
# 791           793       0.0       3            Sage, Miss. Stella Anna
# 844           847       0.0       3           Sage, Mr. Douglas Bullen
# 861           864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"
# 1076         1080       NaN       3                    Sage, Miss. Ada
# 1230         1234       NaN       3              Sage, Mr. John George
# 1248         1252       NaN       3        Sage, Master. William Henry
# 1253         1257       NaN       3     Sage, Mrs. John (Annie Bullen)
#
# ...

# %%
df1 = pd.read_csv('test.csv')

# %%
df = pd.concat([df, df1])

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#       PassengerId  Survived  Pclass                               Name  \
# 158           160       0.0       3         Sage, Master. Thomas Henry
# 179           181       0.0       3       Sage, Miss. Constance Gladys
# 200           202       0.0       3                Sage, Mr. Frederick
# 323           325       0.0       3           Sage, Mr. George John Jr
# 791           793       0.0       3            Sage, Miss. Stella Anna
# 844           847       0.0       3           Sage, Mr. Douglas Bullen
# 861           864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"
# 1076         1080       NaN       3                    Sage, Miss. Ada
# 1230         1234       NaN       3              Sage, Mr. John George
# 1248         1252       NaN       3        Sage, Master. William Henry
# 1253         1257       NaN       3     Sage, Mrs. John (Annie Bullen)
# 188          1080       NaN       3                    Sage, Miss. Ada
# ...

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df['individual_fare'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
df[['individual_fare', 'Fare']].describe()
# Out:
#        individual_fare         Fare
# count      1723.000000  1723.000000
# mean         20.760395    33.805586
# std          35.699541    52.791582
# min           0.000000     0.000000
# 25%           7.550000     7.895800
# 50%           8.654200    14.454200
# 75%          24.500000    31.275000
# max         512.329200   512.329200

# %% [markdown]
# ### On SibSp and Parch

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked deck  individual_fare  \
# 0      0         A/5 21171   7.2500   NaN        S    G          3.62500
# 1      0          PC 17599  71.2833   C85        C    A         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S    G          7.92500
# ...

# %%
# family_type

# 1 --> alone
# 2 - 4 --> small
# >5 --> large

def transform_family_size(number):
    if number == 1:
        return "alone"
    elif number > 1 and number < 5:
        return "small"
    else:
        return "large"

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked deck  individual_fare  \
# 0      0         A/5 21171   7.2500   NaN        S    G          3.62500
# 1      0          PC 17599  71.2833   C85        C    A         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S    G          7.92500
# ...

# %%
pd.crosstab(df['Survived'], df['family_type'], normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.906542  83.870968  42.123288
# 1.0          30.093458  16.129032  57.876712

# %% [markdown]
# ### Feature Engineering on Name

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)

# %%
df['title'].value_counts()
# Out:
# Mr.          996
# Miss.        337
# Mrs.         268
# Master.       82
# Rev.          10
# Dr.            9
# Col.           6
# Ms.            3
# Mlle.          2
# Major.         2
# Dona.          2
# Lady.          1
# Sir.           1
# Mme.           1
# Don.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: title, dtype: int64

# %%
df['title'] = df['title'].str.replace('Rev.', 'other')
df['title'] = df['title'].str.replace('Dr.', 'other')
df['title'] = df['title'].str.replace('Col.', 'other')
df['title'] = df['title'].str.replace('Major.', 'other')
df['title'] = df['title'].str.replace('Don.', 'other')
df['title'] = df['title'].str.replace('Capt.', 'other')
df['title'] = df['title'].str.replace('the', 'other')
df['title'] = df['title'].str.replace('Jonkheer.', 'other')

df['title'] = df['title'].str.replace('Dona.', 'Mrs.')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7872\2929063075.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Rev.', 'other')
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7872\2929063075.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Dr.', 'other')
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7872\2929063075.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Col.', 'other')
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7872\2929063075.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Major.', 'other')
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked deck  individual_fare  \
# 0      0         A/5 21171   7.2500   NaN        S    G          3.62500
# 1      0          PC 17599  71.2833   C85        C    A         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S    G          7.92500
# ...

# %%
temp_df = df[df['title'].isin(['Mr.', 'Miss.', 'Mrs.', 'Master.', 'ootherr'])]

# %%
pd.crosstab(temp_df['Survived'], temp_df['title'], normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.       Mrs.    ootherr
# Survived
# 0.0          42.5  30.38674  84.332689  20.967742  73.684211
# 1.0          57.5  69.61326  15.667311  79.032258  26.315789

# %%
str_col = df.select_dtypes(include=('object')).columns

l_e = LabelEncoder()

for col in str_col:
    df[col] = l_e.fit_transform(df[col].astype('str'))

x = df.drop(['Survived'], axis=True)
y = df[["Survived"]]

# %%
plt.figure(figsize=(18,16))
sns.heatmap(x.corr(), annot=True, cmap=plt.cm.CMRmap_r)
plt.show()
